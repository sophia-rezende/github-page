# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print('Alo mundo')
# Out:
# Alo mundo

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
Numero = float(input('Informa um numero: '))
print(f'O numero informado foi {Numero}')
# Out:
# O numero informado foi 100.0

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
Numero1 = float(input())
Numero2 = float(input())
print(Numero1 + Numero2)
# Out:
# 35.0

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %%
Nota1 = float(input())
Nota2 = float(input())
Nota3 = float(input())
Nota4 = float(input())

Media = (Nota1 + Nota2 + Nota3 + Nota4) / 4
print(f'A media e {Media}')
# Out:
# A media e 5.5

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
Metro = float(input('O comprimento e de: '))
centrimetos = Metro * 100
print(f'{Metro}m é igual a {centrimetos}cm')
# Out:
# 6.0m é igual a 600.0cm

# %% [markdown]
# #### 6. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
Largura = float(input('Informe a lagura em metros da sala: '))
Comprimento = float(input('Informe o comprimento em metros da sala: '))
Area = Largura * Comprimento

print(f'A area da sala e de {Area}m2')
# Out:
# A area da sala e de 45000.0m2

# %% [markdown]
# #### 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
GanhoHora = float(input('Informe o valor ganho por hora: R$ '))
HorasTrabalhadas = float(input('Informe a quantidade de horas trabalhadas em um mes: '))
Salario = GanhoHora * HorasTrabalhadas

print(f'O salario do mes foi de = R$ {Salario}')
# Out:
# O salario do mes foi de = R$ 5200.0

# %% [markdown]
# #### 8. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
TemperaturaF = float(input('informe a temperatura em Fahrenheit: '))
C = (5/9) * (TemperaturaF - 32)

print(f'A temperatura em Celsius e de {C}°C')
# Out:
# A temperatura em Celsius e de 121.11111111111111°C

# %% [markdown]
# #### 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
TemperaturaC = float(input('informe a temperatura em Celsius: '))
F = (9/5) * (TemperaturaC) + 32

print(f'A temperatura em Fahrenheit e de {F}°F')

# %% [markdown]
# #### 10. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
h = float(input('Informe sua altura em metros: '))
P = (72.7 * h) - 58
print(f'Seu peso ideal e: {P} kg')

# %% [markdown]
# #### 11. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
h = float(input('Informe sua altura em metros: '))
PHomen = (72.7 * h) - 58
PMulher = (62.1 * h) - 44.7
print(f'O peso ideal com essa altura para homens é: {PHomen} kg')
print(f'O peso ideal com essa altura para mulheres é: {PMulher} kg')

# %% [markdown]
# #### 12. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
GanhoHora = float(input('Informe quanto voce ganha por hora: R$ '))
HorasTrabalhadas = float(input('Informe a quantidade de horas trabalhadas no mes: '))

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
SalarioBruto = GanhoHora * HorasTrabalhadas
print(f'O salário bruto é R$ {salario_bruto}')

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
DescontoIR = (11/100) * SalarioBruto
print(f'O desconto do IR é R$ {DescontoIR}')

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
DescontoINSS = (8/100) * SalarioBruto
print(f'O desconto do INSS é R$ {DescontoINSS}')

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
DescontoSindicato = (5/100) * SalarioBruto
print(f'O desconto do sindicato é R$ {DescontoSindicato}')

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
SalarioLiquido = (SalarioBruto - DescontoIR - DescontoINSS - DescontoSindicato)
print(f'O salário líquido é R$ {SalarioLiquido}')

# %% [markdown]
# #### 13. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
AreaPintada = float(input('Informe o tamanho em metros quadrados da area a ser pintada:'))
CoberturaTinta = 1/3
LitrosTinta = 18
CustoTinta = 80
QtdeComprar = (CoberturaTinta * AreaPintada) / LitrosTinta
PrecoComprar = (QtdeComprar * CustoTinta)

print (f'A quantidade de latas de tinta para pintar a area de {AreaPintada} e de {QtdeComprar} e o preco total de {PrecoComprar}')
# Out:
# A quantidade de latas de tinta para pintar a area de 25.0 e de 0.4629629629629629 e o preco total de 37.03703703703703

# %% [markdown]
# #### 14. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
TamanhoArquivo = float(input('Informe o tamanho do arquivo para download em MB: '))
VelocidadeInternet = float(input('Informe a velocidade de um link de internet em Mbps: '))
Tempo = ((TamanhoArquivo * 8) / VelocidadeInternet) / 60 

print(f'O tempo aproximado de download do arquivo usando este link e: {Tempo} minutos')
# Out:
# O tempo aproximado de download do arquivo usando este link e: 13.333333333333334 minutos
